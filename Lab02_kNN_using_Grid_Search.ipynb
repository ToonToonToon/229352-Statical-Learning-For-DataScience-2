# %% [markdown]
# <a href="https://colab.research.google.com/github/ToonToonToon/229352-Statical-Learning-For-DataScience-2/blob/main/Lab02_kNN_using_Grid_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Statistical Learning for Data Science 2 (229352)
# #### Instructor: Donlapark Ponnoprat
#
# #### [Course website](https://donlapark.pages.dev/229352/)
#
# ## Lab #3

# %%
from sklearn.datasets import fetch_20newsgroups

train = fetch_20newsgroups(subset='train')
test = fetch_20newsgroups(subset='test')

Xtrain = train.data[:3000]
ytrain = train.target[:3000]
Xtest = test.data[:500]
ytest = test.target[:500]

print("X:", len(Xtest))
print("y:", len(ytest))
# Out:
# X: 500
# y: 500

# %%
print("X[0]:", Xtrain[0])
print("y[0]:", ytrain[0])
# Out:
# X[0]: From: lerxst@wam.umd.edu (where's my thing)
# Subject: WHAT car is this!?
# Nntp-Posting-Host: rac3.wam.umd.edu
# Organization: University of Maryland, College Park
# Lines: 15
#
#  I was wondering if anyone out there could enlighten me on this car I saw
# the other day. It was a 2-door sports car, looked to be from the late 60s/
# early 70s. It was called a Bricklin. The doors were really small. In addition,
# the front bumper was separate from the rest of the body. This is
# all I know. If anyone can tellme a model name, engine specs, years
# of production, where this car is made, history, or whatever info you
# have on this funky looking car, please e-mail.
#
# Thanks,
# - IL
#    ---- brought to you by your neighborhood Lerxst ----
#
#
#
#
#
# y[0]: 7

# %%
train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# ### Apply Tfidf ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# define transformation
tfidf = TfidfVectorizer(stop_words="english",ngram_range=(1,1))

# fit+transform training set
Xtrain_tfidf = tfidf.fit_transform(Xtrain)
Xtest_tfidf = tfidf.transform(Xtest) # Only transform the test set, do not fit again

# See output
Xtrain_tfidf
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 341881 stored elements and shape (3000, 61689)>

# %%
tfidf.vocabulary_
# Out:
# {'v064mb9k': 15188,
#  'ubvmsd': 14845,
#  'cc': 3542,
#  'buffalo': 3163,
#  'edu': 5614,
#  'neil': 10172,
#  'gandler': 6718,
#  'subject': 13911,
#  'need': 10153,
#  'info': 7932,
#  '88': 1311,
#  '89': 1321,
#  'bonneville': 2971,
#  'organization': 10617,
#  'university': 15009,
#  'lines': 8989,
#  '10': 87,
#  'news': 10213,
#  'software': 13453,
#  'vax': 15248,
#  'vms': 15383,
#  'vnews': 15385,
#  '41': 894,
#  'nntp': 10293,
#  'posting': 11333,
#  'host': 7546,
#  'little': 9023,
#  'confused': 4211,
#  'models': 9807,
#  'bonnevilles': 2972,
#  'heard': 7315,
#  'le': 8820,
#  'se': 12864,
#  'lse': 9162,
#  'sse': 13658,
#  'ssei': 13659,
#  'tell': 14293,
#  'differences': 5120,
#  'far': 6224,
#  'features': 6268,
#  'performance': 10978,
#  'curious': 4628,
#  'know': 8628,
#  'book': 2977,
#  'value': 15223,
#  'prefereably': 11418,
#  'model': 9804,
#  'usually': 15139,
#  'words': 15756,
#  'demand': 4924,
#  'time': 14466,
#  'year': 15943,
#  'mid': 9669,
#  'spring': 13626,
#  'early': 5550,
#  'summer': 13983,
#  'best': 2748,
#  'buy': 3230,
#  'rick': 12411,
#  'miller': 9688,
#  'ee': 5621,
#  'uwm': 15178,
#  'face': 6155,
#  'just': 8428,
#  '17': 306,
#  'distribution': 5265,
#  'world': 15771,
#  '129': 187,
#  '33': 800,
#  'summary': 13981,
#  'ahead': 1815,
#  'swamp': 14084,
#  'eep': 5631,
#  'familiar': 6204,
#  'format': 6527,
#  'thingies': 14388,
#  'seeing': 12912,
#  'folks': 6475,
#  'headers': 7303,
#  've': 15255,
#  'got': 6951,
#  'maybe': 9467,
#  'make': 9293,
#  'dpg': 5388,
#  'view': 15327,
#  'linux': 8998,
#  'box': 3036,
#  'displays': 5240,
#  'uncompressed': 14935,
#  'faces': 6159,
#  'managed': 9311,
#  'compile': 4099,
#  'compface': 4098,
#  'looking': 9093,
#  'anyones': 2078,
#  'send': 12956,
#  'header': 7302,
#  'll': 9037,
#  'probably': 11517,
#  'swamped': 14085,
#  'handle': 7195,
#  'hope': 7518,
#  'ricxjo': 12415,
#  'discus': 5206,
#  'mil': 9679,
#  'wi': 15629,
#  'muelisto': 9990,
#  'postcard': 11329,
#  'enposxtigu': 5818,
#  'bildkarton': 2809,
#  'kaj': 8459,
#  'vi': 15311,
#  'ricevos': 12403,
#  'alion': 1892,
#  '16203': 289,
#  'woods': 15746,
#  'muskego': 10029,
#  'wis': 15696,
#  '53150': 1010,
#  'usa': 15115,
#  'mathew': 9438,
#  'mantis': 9342,
#  'uk': 14883,
#  'strong': 13871,
#  'weak': 15545,
#  'atheism': 2331,
#  'consultants': 4273,
#  'cambridge': 3356,
#  'newsreader': 10222,
#  'rusnews': 12603,
#  'v1': 15190,
#  '02': 22,
#  'acooper': 1643,
#  'mac': 9221,
#  'macalstr': 9223,
#  'turin': 14780,
#  'turambar': 14773,
#  'department': 4957,
#  'utter': 15159,
#  'misery': 9742,
#  'writes': 15811,
#  'did': 5106,
#  'faq': 6221,
#  'modified': 9816,
#  'define': 4880,
#  'atheists': 2333,
#  'assert': 2279,
#  'nonexistence': 10312,
#  'god': 6913,
#  'believe': 2706,
#  'word': 15752,
#  'yes': 15952,
#  'bakken': 2515,
#  'cs': 4574,
#  'arizona': 2197,
#  'dave': 4764,
#  'saudi': 12723,
#  'clergy': 3885,
#  'condemns': 4177,
#  'debut': 4828,
#  'human': 7613,
#  'rights': 12429,
#  'group': 7057,
#  'keywords': 8542,
#  'international': 8089,
#  'non': 10305,
#  'government': 6960,
#  'civil': 3827,
#  'social': 13434,
#  'issues': 8212,
#  'politics': 11260,
#  'dept': 4971,
#  'tucson': 14760,
#  '101': 94,
#  'article': 2241,
#  'benali': 2721,
#  '737307554': 1204,
#  'alcor': 1874,
#  'concordia': 4171,
#  'ca': 3303,
#  'ilyess': 7767,
#  'bdira': 2630,
#  'looks': 9094,
#  'like': 8962,
#  'ben': 2720,
#  'baz': 2615,
#  'mind': 9701,
#  'heart': 7318,
#  'blind': 2897,
#  'eyes': 6138,
#  'used': 15123,
#  'respect': 12306,
#  'today': 14509,
#  'lost': 9117,
#  'minimal': 9709,
#  'struggled': 13882,
#  'muslim': 10032,
#  'netters': 10194,
#  'guy': 7130,
#  'gave': 6758,
#  'fatwah': 6238,
#  'arabia': 2160,
#  'united': 14998,
#  'ststes': 13884,
#  'attack': 2357,
#  'iraq': 8164,
#  'attacking': 2359,
#  'iraqis': 8166,
#  'drive': 5431,
#  'kuwait': 8682,
#  'country': 4439,
#  'citizens': 3821,
#  'close': 3912,
#  'blood': 2904,
#  'business': 3219,
#  'ties': 14456,
#  'thinks': 14393,
#  'helped': 7356,
#  'swallowed': 14083,
#  'eastern': 5564,
#  'oilfields': 10518,
#  'doing': 5328,
#  'help': 7355,
#  'liberate': 8930,
#  'protect': 11613,
#  'masses': 9418,
#  'demonstrating': 4937,
#  'favor': 6244,
#  'butcher': 3225,
#  'saddam': 12648,
#  'killed': 8564,
#  'lotsa': 9122,
#  'muslims': 10033,
#  'killing': 8568,
#  'raping': 11876,
#  'looting': 9106,
#  'relatively': 12124,
#  'rich': 12404,
#  'thumbing': 14437,
#  'nose': 10339,
#  'west': 15594,
#  'defended': 4873,
#  'rolled': 12504,
#  'iraqi': 8165,
#  'invasion': 8129,
#  'charge': 3665,
#  'legitimate': 8872,
#  'kind': 8577,
#  'islamic': 8196,
#  'duty': 5512,
#  'separate': 12981,
#  'religion': 12142,
#  'means': 9521,
#  'official': 10503,
#  'think': 14391,
#  'good': 6938,
#  'idea': 7695,
#  'governments': 6961,
#  'facto': 6167,
#  'jure': 8425,
#  'nature': 10115,
#  'ambitious': 1953,
#  'pious': 11128,
#  'ones': 10546,
#  'rise': 12442,
#  'power': 11351,
#  'people': 10963,
#  'really': 11950,
#  'leader': 8823,
#  'devout': 5069,
#  'slick': 13361,
#  'operator': 10572,
#  'cairo': 3323,
#  'egypt': 5652,
#  'upi': 15089,
#  'based': 2580,
#  'arab': 2159,
#  'aohr': 2084,
#  'thursday': 14442,
#  'welcomed': 15579,
#  'establishement': 5936,
#  'week': 15566,
#  'committee': 4060,
#  'defense': 4875,
#  'legal': 8861,
#  'said': 12661,
#  'necessary': 10147,
#  'groups': 7058,
#  'operating': 10569,
#  'countries': 4438,
#  'sound': 13500,
#  'guys': 7132,
#  'angels': 2023,
#  'clarinet': 3848,
#  'edited': 5601,
#  'stuff': 13894,
#  'following': 6479,
#  'friday': 6611,
#  'new': 10205,
#  'york': 15966,
#  'times': 14468,
#  'reported': 12220,
#  'definitely': 4885,
#  'conservative': 4239,
#  'sheikh': 13103,
#  'followers': 6478,
#  'house': 7563,
#  'saud': 12722,
#  'does': 5319,
#  'rule': 12587,
#  'conservatively': 4240,
#  'nyt': 10411,
#  'complaining': 4106,
#  'asserted': 2281,
#  'approx': 2147,
#  '500': 976,
#  '000': 1,
#  'shiites': 13127,
#  'kingdom': 8585,
#  'apostates': 2106,
#  'law': 8788,
#  'brings': 3102,
#  'death': 4814,
#  'penalty': 10948,
#  'diplomatic': 5156,
#  'bin': 2815,
#  'jibrin': 8320,
#  'isn': 8201,
#  'called': 3344,
#  'severe': 13032,
#  'punishment': 11705,
#  '40': 881,
#  'women': 15736,
#  'drove': 5445,
#  'public': 11678,
#  'protest': 11618,
#  'ban': 2528,
#  'driving': 5437,
#  'abdelhamoud': 1554,
#  'al': 1849,
#  'toweijri': 14585,
#  'fired': 6379,
#  'jobs': 8343,
#  'jailed': 8246,
#  'branded': 3062,
#  'prostitutes': 11612,
#  'want': 15484,
#  'happen': 7214,
#  'say': 12736,
#  'basis': 2588,
#  'qur': 11805,
#  'ahadith': 1814,
#  'falsely': 6202,
#  'choose': 3753,
#  'heroes': 7384,
#  'wisely': 15703,
#  'reflexively': 12066,
#  'rally': 11848,
#  'hates': 7264,
#  'hate': 7261,
#  'allowed': 1915,
#  'work': 15758,
#  'tv': 14798,
#  'radio': 11826,
#  'immoral': 7784,
#  'favorite': 6247,
#  'earth': 5552,
#  'restrict': 12330,
#  'religious': 12144,
#  'political': 11257,
#  'reedom': 12041,
#  'lot': 9118,
#  'things': 14389,
#  'likely': 8964,
#  'replacements': 12208,
#  'going': 6922,
#  'worse': 15780,
#  'feeling': 6284,
#  'heat': 7321,
#  'lately': 8766,
#  'months': 9867,
#  'read': 11930,
#  'stepped': 13767,
#  'harassing': 7220,
#  'muttawain': 10038,
#  'police': 11253,
#  'western': 15595,
#  'fully': 6654,
#  'veiled': 15270,
#  'stupid': 13899,
#  'imo': 7787,
#  'sends': 12961,
#  'wrong': 15815,
#  'signals': 13223,
#  'morality': 9879,
#  'cracked': 4477,
#  'home': 7491,
#  'expartiate': 6062,
#  'gatherings': 6752,
#  'posted': 11330,
#  'rewards': 12382,
#  'owned': 10724,
#  'newspapers': 10221,
#  'offering': 10497,
#  'money': 9851,
#  'turns': 14792,
#  'expartiates': 6063,
#  'dare': 4737,
#  'worship': 15782,
#  'homes': 7497,
#  'secret': 12896,
#  'place': 11160,
#  'grown': 7063,
#  'intolerant': 8114,
#  'try': 14738,
#  'wind': 15662,
#  'sails': 12664,
#  'opposition': 10583,
#  'unislamic': 14993,
#  'small': 13394,
#  'taste': 14213,
#  'overthrow': 10714,
#  'trying': 14739,
#  'long': 9088,
#  'run': 12593,
#  'rached': 11816,
#  'general': 6784,
#  'evil': 5991,
#  'zionists': 16014,
#  'puppet': 11709,
#  'crowd': 4549,
#  'president': 11453,
#  'fine': 6363,
#  'job': 8341,
#  'problem': 11519,
#  'don': 5341,
#  'husband': 7638,
#  'james': 8251,
#  'carville': 3465,
#  'clinton': 3903,
#  'campaign': 3365,
#  'strategist': 13835,
#  '93': 1361,
#  'oh': 10511,
#  'daddy': 4695,
#  'mom': 9841,
#  'busy': 3224,
#  'chelsea': 3705,
#  'nurse': 10396,
#  'cspan': 4587,
#  'livesey': 9031,
#  'solntze': 13469,
#  'wpd': 15795,
#  'sgi': 13047,
#  'com': 4025,
#  'jon': 8363,
#  '2000': 523,
#  'years': 15944,
#  'christian': 3765,
#  '22': 590,
#  '1993apr21': 430,
#  '141259': 219,
#  '12012': 161,
#  'st': 13662,
#  'andrews': 2012,
#  'ac': 1590,
#  'nrp': 10366,
#  'norman': 10327,
#  'paterson': 10881,
#  '1r2m21': 481,
#  '8mo': 1333,
#  'fido': 6326,
#  'asd': 2255,
#  '1993apr19': 428,
#  '151902': 254,
#  '21216': 573,
#  'claiming': 3840,
#  'moral': 9878,
#  'absolute': 1579,
#  'list': 9006,
#  'references': 12053,
#  'stretching': 13851,
#  'alpha': 1923,
#  'centauri': 3585,
#  'deleted': 4912,
#  'thought': 14411,
#  'impress': 7821,
#  'ok': 10523,
#  'claim': 3838,
#  'objective': 10436,
#  'assume': 2299,
#  'answer': 2054,
#  'apologies': 2102,
#  'spent': 13581,
#  'solid': 13467,
#  'arguing': 2187,
#  'thing': 14386,
#  'exists': 6056,
#  'banschbach': 2546,
#  'ocom': 10476,
#  'okstate': 10527,
#  'candida': 3383,
#  'yeast': 15945,
#  'bloom': 2910,
#  'fact': 6164,
#  'fiction': 6322,
#  'osu': 10649,
#  'college': 4001,
#  'osteopathic': 10648,
#  'medicine': 9549,
#  '91': 1349,
#  '1rp8p1': 503,
#  '2d3': 744,
#  'usenet': 15127,
#  'ins': 7989,
#  'cwru': 4663,
#  'esd3': 5920,
#  'po': 11232,
#  'elisabeth': 5705,
#  'davidson': 4771,
#  'previous': 11472,
#  'says': 12738,
#  'enlightened': 5814,
#  'physicians': 11086,
#  'practicing': 11381,
#  'bad': 2506,
#  'medical': 9546,
#  'schools': 12796,
#  'cover': 4457,
#  'nutrition': 10398,
#  'viewed': 15328,
#  'disease': 5213,
#  'profession': 11548,
#  'case': 3472,
#  'reserve': 12273,
#  'med': 9538,
#  'school': 12795,
#  'teaches': 14242,
#  'section': 12900,
#  'covering': 4460,
#  'sections': 12901,
#  'apply': 2133,
#  'b12': 2472,
#  'deficiency': 4878,
#  'neuro': 10198,
#  'cause': 3518,
#  'neuropathy': 10200,
#  'hematology': 7360,
#  'megaloblastic': 9561,
#  'anemia': 2017,
#  'sill': 13239,
#  'hold': 7473,
#  'viewpoint': 15333,
#  'mainstream': 9282,
#  'mucocutaneous': 9986,
#  'candidiasis': 3385,
#  'sick': 13199,
#  'patients': 10886,
#  'damaged': 4711,
#  'immune': 7786,
#  'systems': 14139,
#  'aids': 1824,
#  'cancer': 3382,
#  'systemic': 14138,
#  'infection': 7918,
#  'connection': 4223,
#  'bunch': 3187,
#  'hooey': 7515,
#  'taught': 14216,
#  'let': 8898,
#  'set': 13018,
#  'record': 12009,
#  'straight': 13826,
#  'nth': 10377,
#  'brainwashing': 3056,
#  'hated': 7262,
#  'okay': 10524,
#  'guess': 7098,
#  'quote': 11801,
#  'zinsser': 16011,
#  'microbiology': 9655,
#  '20th': 561,
#  'edition': 5603,
#  'species': 13549,
#  'colonize': 4011,
#  'mucosal': 9987,
#  'surfaces': 14041,
#  'humans': 7616,
#  'birth': 2839,
#  'shortly': 13163,
#  'risk': 12445,
#  'endogenous': 5779,
#  'clearly': 3880,
#  'present': 11443,
#  'occurs': 10472,
#  'worldwide': 15774,
#  'common': 4064,
#  'mycosis': 10047,
#  'neutrophils': 10203,
#  'play': 11194,
#  'main': 9279,
#  'role': 12501,
#  'preventing': 11469,
#  'low': 9142,
#  'neutrophil': 10202,
#  'count': 4430,
#  'poor': 11287,
#  'diet': 5115,
#  'persistent': 11008,
#  'parasitic': 10813,
#  'infestation': 7923,
#  'residents': 12278,
#  'assessment': 2287,
#  'correct': 4397,
#  'dispute': 5247,
#  'discussion': 5211,
#  'blooms': 2912,
#  'responsible': 12319,
#  'local': 9060,
#  'sites': 13295,
#  'irritation': 8181,
#  'gi': 6842,
#  'tract': 14606,
#  'mouth': 9930,
#  'vagina': 15208,
#  'sinus': 13288,
#  'cavity': 3526,
#  'knocking': 8627,
#  'bacterial': 2505,
#  'competition': 4096,
#  'proposed': 11603,
#  'possible': 11325,
#  'trigger': 14691,
#  'factors': 6170,
#  'use': 15122,
#  'broad': 3109,
#  'spectrum': 13565,
#  'antibacterial': 2067,
#  'antibiotic': 2068,
#  'predispose': 11414,
#  'infections': 7919,
#  'addressing': 1691,
#  'term': 14319,
#  'better': 2755,
#  'course': 4449,
#  'teach': 14239,
#  'covers': 4461,
#  'effect': 5634,
#  'treatment': 14669,
#  'cure': 4624,
#  'brief': 3095,
#  'primer': 11484,
#  'commonly': 4065,
#  'truely': 14726,
#  'caused': 3519,
#  'yeasts': 15946,
#  'organism': 10616,
#  'type': 14820,
#  'albicans': 1865,
#  'monilia': 9854,
#  'actually': 1667,
#  'fungus': 6673,
#  'getting': 6833,
#  'picky': 11097,
#  'form': 6523,
#  'exist': 6050,
#  'mold': 9831,
#  'fungi': 6672,
#  'occur': 10468,
#  'molds': 9833,
#  'depending': 4961,
#  'environment': 5851,
#  'exibits': 6049,
#  'known': 8633,
#  'reverse': 12370,
#  'dimorphism': 5146,
#  'tissues': 14488,
#  'martin': 9396,
#  'ph': 11042,
#  'professor': 11551,
#  'biochemistry': 2827,
#  'chairman': 3625,
#  '1111': 131,
#  '17th': 338,
#  'tulsa': 14767,
#  '74107': 1207,
#  'biochem': 2825,
#  'micro': 9653,
#  'didn': 5107,
#  'shudder': 13186,
#  'oversimplifying': 10712,
#  'detect': 5027,
#  'steve': 13773,
#  'dyer': 5529,
#  'noticed': 10349,
#  'faculty': 6174,
#  'rank': 11870,
#  'biochemist': 2826,
#  'microbiologist': 9654,
#  'classifed': 3856,
#  'according': 1615,
#  'point': 11243,
#  'capable': 3404,
#  'producing': 11540,
#  'cells': 3575,
#  'pseudohyphae': 11651,
#  'true': 14725,
#  'hyphae': 7663,
#  'makes': 9297,
#  'sense': 12964,
#  'greek': 7019,
#  'crucify': 4557,
#  'haven': 7272,
#  'able': 1563,
#  'figure': 6339,
#  'bring': 3100,
#  'hostility': 7551,
#  'sci': 12802,
#  'admitt': 1721,
#  'sucked': 13947,
#  'mud': 9989,
#  'slinging': 13367,
#  'hoping': 7521,
#  'asking': 2267,
#  'plain': 11165,
#  'simple': 13254,
#  'honest': 7509,
#  'beginning': 2683,
#  'wish': 15704,
#  'written': 15814,
#  'marty': 9399,
#  'petch': 11024,
#  'gvg47': 7137,
#  'gvg': 7136,
#  'tek': 14281,
#  'chuck': 3776,
#  'daily': 4701,
#  'verse': 15292,
#  'dishonest': 5220,
#  'dwindles': 5519,
#  'away': 2446,
#  'gathers': 6753,
#  'grow': 7060,
#  'proverbs': 11629,
#  '13': 189,
#  '11': 127,
#  'fortmann': 6546,
#  'superbowl': 14003,
#  'und': 14942,
#  'za': 15989,
#  'paul': 10895,
#  'pg': 11036,
#  'perfect': 10974,
#  'exe': 6034,
#  'file': 6343,
#  'needed': 10154,
#  'natal': 10097,
#  'durban': 5505,
#  '14': 215,
#  'friend': 6613,
#  'copy': 4373,
#  'computerised': 4144,
#  'hebrew': 7331,
#  'lexicon': 8914,
#  'processing': 11532,
#  'package': 10753,
#  'wordperfect': 15754,
#  'wiped': 15691,
#  'restore': 12327,
#  'distributors': 5266,
#  'south': 13508,
#  'africa': 1783,
#  'appreciate': 2136,
#  'email': 5722,
#  'address': 1688,
#  'shrike': 13182,
#  'thanks': 14355,
#  'kartik': 8481,
#  'hls': 7452,
#  'chandrasekhar': 3639,
#  'multiple': 10002,
#  'simultaneous': 13266,
#  'server': 13008,
#  'connections': 4224,
#  'internet': 8090,
#  'enterpoop': 5830,
#  'mit': 9768,
#  'xpert': 15890,
#  'expo': 6103,
#  'lcs': 8814,
#  'hi': 7399,
#  'requirement': 12248,
#  'dynamically': 5532,
#  'closing': 3919,
#  'opening': 10562,
#  'different': 5121,
#  'display': 5238,
#  'servers': 13009,
#  'application': 2129,
#  'manner': 9337,
#  'associated': 2295,
#  'client': 3892,
#  'assumming': 2303,
#  'proper': 11594,
#  'cleanup': 3874,
#  'transition': 14646,
#  'anticipate': 2069,
#  'problems': 11521,
#  'tmc': 14497,
#  'spartan': 13533,
#  'brocku': 3115,
#  'tim': 14465,
#  'ciceran': 3789,
#  'turning': 14790,
#  'photographic': 11071,
#  'images': 7770,
#  'thermal': 14378,
#  'print': 11491,
#  'negatives': 10162,
#  'brock': 3114,
#  'catharines': 3500,
#  'ontario': 10551,
#  'tin': 14475,
#  'version': 15294,
#  'pl9': 11159,
#  'jennifer': 8288,
#  'lynn': 9206,
#  'urso': 15113,
#  'ju23': 8404,
#  'andrew': 2011,
#  'cmu': 3943,
#  'wrote': 15820,
#  'lots': 9121,
#  'experience': 6074,
#  'scanning': 12761,
#  'altering': 1930,
#  'changing': 3646,
#  'bitter': 2861,
#  'woman': 15734,
#  'blahness': 2879,
#  'cheerful': 3698,
#  'undertones': 14958,
#  'aldus': 1875,
#  'photostyler': 11076,
#  'pc': 10914,
#  'turn': 14786,
#  'colour': 4020,
#  'black': 2869,
#  'white': 15616,
#  'image': 7769,
#  'negative': 10161,
#  'works': 15767,
#  'test': 14333,
#  'scanned': 12758,
#  'create': 4502,
#  'positive': 11314,
#  'looked': 9092,
#  'film': 6351,
#  'developers': 5050,
#  'greg': 7027,
#  'reinacker': 12109,
#  'ftcollins': 6636,
#  'ncr': 10130,
#  'windows': 15668,
#  'line': 8985,
#  'review': 12373,
#  'uploaded': 15093,
#  'reply': 12216,
#  'ftcollinsco': 6637,
#  'microelectronics': 9660,
#  'ft': 6635,
#  'collins': 4002,
#  '12': 158,
#  'shareware': 13085,
#  'ftp': 6639,
#  'cica': 3788,
#  'indiana': 7887,
#  'pub': 11677,
#  'win3': 15659,
#  'uploads': 15094,
#  'wolrs7': 15730,
#  'zip': 16015,
#  'magazine': 9259,
#  'contains': 4286,
#  'reviews': 12375,
#  'products': 11545,
#  'grabbed': 6968,
#  'bbs': 2619,
#  '303': 757,
#  '223': 597,
#  '5100': 989,
#  'x9289': 15855,
#  'microelectronic': 9659,
#  'division': 5281,
#  'voiceplus': 15391,
#  '464': 937,
#  '9289': 1359,
#  '2001': 524,
#  'danfield': 4725,
#  'court': 4451,
#  'fort': 6542,
#  '80525': 1253,
#  'sirosh': 13291,
#  'utexas': 15148,
#  'joseph': 8373,
#  'design': 4992,
#  'choice': 3750,
#  'color': 4012,
#  'handling': 7200,
#  'question': 11782,
#  'texas': 14341,
#  'austin': 2401,
#  '16': 276,
#  'cascais': 3471,
#  'graphics': 6995,
#  'seen': 12918,
#  'drawing': 5412,
#  'routines': 12550,
#  'specify': 13556,
#  'drawpoint': 5416,
#  'drawline': 5414,
#  'x1': 15840,
#  'y1': 15923,
#  'x2': 15845,
#  'y2': 15924,
#  'fillrectangle': 6349,
#  'xsetforeground': 15905,
#  'current_color': 4631,
#  'xdrawpoint': 15861,
#  'split': 13599,
#  'functions': 6663,
#  'designers': 4997,
#  'decide': 4838,
#  'associate': 2294,
#  'object': 10432,
#  'drawn': 5415,
#  'instead': 8011,
#  'tclock': 14232,
#  'orion': 10634,
#  'oac': 10416,
#  'uci': 14855,
#  'clock': 3909,
#  'peace': 10929,
#  'talks': 14172,
#  'california': 3342,
#  'irvine': 8182,
#  '38': 854,
#  '1993may13': 443,
#  '201441': 530,
#  '23139': 618,
#  'nysernet': 10409,
#  'org': 10613,
#  'astein': 2310,
#  'alan': 1852,
#  'stein': 13755,
#  'israel': 8204,
#  'making': 9298,
#  'goodwill': 6943,
#  'gesture': 6830,
#  'palestinian': 10778,
#  'arabs': 2161,
#  'continue': 4300,
#  'hunting': 7630,
#  'jews': 8307,
#  'putting': 11732,
#  'newsgroup': 10216,
#  'generate': 6789,
#  'flames': 6412,
#  'adding': 1684,
#  'substance': 13924,
#  'issue': 8210,
#  'gestures': 6831,
#  'mentioned': 9591,
#  'realistic': 11945,
#  'chance': 3637,
#  'success': 13938,
#  'start': 13704,
#  'reciprocating': 11993,
#  'especially': 5926,
#  'tangible': 14186,
#  'concessions': 4164,
#  'return': 12358,
#  'giving': 6866,
#  'intangibles': 8037,
#  'feel': 6283,
#  'offered': 10496,
#  'realistically': 11946,
#  'expect': 6064,
#  'presented': 11446,
#  'palestinians': 10779,
#  'way': 15535,
#  'change': 3641,
#  'agreed': 1807,
#  'rules': 12589,
#  'games': 6714,
#  'israelis': 8206,
#  'confident': 4193,
#  'receive': 11983,
#  'bargaining': 2559,
#  'table': 14146,
#  ...}

# %% [markdown]
# #### Exercise 1: Find post in the training set that is closest in tf-idf to the first post in the test set (`Xtest[0]`). Print the content of both posts (not the tf-idf vectors).

# %%
from sklearn.metrics.pairwise import euclidean_distances
import numpy as np

# 1. คำนวณระยะห่างระหว่างเวกเตอร์แรกของ Test set กับเวกเตอร์ทั้งหมดใน Training set
# euclidean_distances จะคืนค่าออกมาเป็น array ของระยะห่าง
distances = euclidean_distances(Xtest_tfidf[0], Xtrain_tfidf)

# 2. หา Index ของโพสต์ที่มีระยะห่างน้อยที่สุด (ใกล้ที่สุด)
closest_index = np.argmin(distances)

# 3. แสดงผลลัพธ์
print(f"Found closest post at index: {closest_index}")
print("=" * 50)
print("--- Content of the first post in Test set (Xtest[0]) ---")
print(Xtest[0])
print("=" * 50)
print(f"--- Content of the closest post in Training set (Xtrain[{closest_index}]) ---")
print(Xtrain[closest_index])
# Out:
# Found closest post at index: 2577
# ==================================================
# --- Content of the first post in Test set (Xtest[0]) ---
# From: v064mb9k@ubvmsd.cc.buffalo.edu (NEIL B. GANDLER)
# Subject: Need info on 88-89 Bonneville
# Organization: University at Buffalo
# Lines: 10
# News-Software: VAX/VMS VNEWS 1.41
# Nntp-Posting-Host: ubvmsd.cc.buffalo.edu
#
#
#  I am a little confused on all of the models of the 88-89 bonnevilles.
# I have heard of the LE SE LSE SSE SSEI. Could someone tell me the
# differences are far as features or performance. I am also curious to
# know what the book value is for prefereably the 89 model. And how much
# less than book value can you usually get them for. In other words how
# much are they in demand this time of year. I have heard that the mid-spring
# early summer is the best time to buy.
#
# 			Neil Gandler
#
# ==================================================
# --- Content of the closest post in Training set (Xtrain[2577]) ---
# From: v063kcbp@ubvmsd.cc.buffalo.edu (MITCH)
# Subject: Thanks! (Backing Up Masters)
# Keywords: Misled, Confused, Advice, Comprendo!
# Organization: University at Buffalo
# Lines: 8
# News-Software: VAX/VMS VNEWS 1.41
# Nntp-Posting-Host: ubvmsd.cc.buffalo.edu
#
#
# 	Just a quick THANKS to the many who explained the backing up of my
# masters.  Apparently they are NOT copy-protected; I just used a program that
# is unable to handle high-density (old shit).  I was surprised to hear that
# "NO programs on high-density disks have copy protection," which someone
# back there said.  Huh!  Learn something new every day!
#
# 						- Mitch

# %% [markdown]
# ### Classify with k-Nearest Neighbor (kNN) ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html))

# %%
from sklearn.neighbors import KNeighborsClassifier

# Define model
nb = KNeighborsClassifier(n_neighbors=3)

# Fit the model
nb.fit(Xtrain_tfidf, ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# Evaluate on the test set using [`classification_report`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html)
#
# We will focus on the [F1-score](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html)

# %%
from sklearn.metrics import classification_report
import numpy as np
# Make predictions on the test set
ypred = nb.predict(Xtest_tfidf)
np.array(train.target_names)[ypred]
# Report classification scores
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.62      0.51        21
#            1       0.33      0.62      0.43        21
#            2       0.38      0.62      0.47        26
#            3       0.35      0.47      0.40        34
#            4       0.47      0.44      0.45        34
#            5       0.70      0.54      0.61        26
#            6       0.44      0.55      0.49        22
#            7       0.70      0.57      0.63        28
#            8       0.75      0.73      0.74        33
#            9       0.67      0.64      0.65        25
#           10       0.83      0.70      0.76        27
#           11       0.80      0.80      0.80        20
#           12       0.50      0.21      0.29        24
#           13       0.79      0.65      0.71        23
#           14       0.82      0.64      0.72        28
#           15       0.76      0.66      0.70        29
#           16       0.54      0.62      0.58        21
#           17       0.82      0.78      0.80        18
#           18       0.72      0.50      0.59        26
#           19       0.33      0.14      0.20        14
#
#     accuracy                           0.58       500
#    macro avg       0.61      0.57      0.58       500
# weighted avg       0.61      0.58      0.58       500

# %% [markdown]
# ### Combine all methods into a [pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([('tfidf',TfidfVectorizer()),('nb',KNeighborsClassifier())])

# Fit the pipeline to the training set
pipeline.fit(Xtrain,ytrain)

# Make predictions on the test set
ypred = pipeline.predict(Xtest)

# report classification scores
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.18      0.48      0.26        21
#            1       0.38      0.48      0.43        21
#            2       0.56      0.58      0.57        26
#            3       0.52      0.50      0.51        34
#            4       0.67      0.53      0.59        34
#            5       0.88      0.54      0.67        26
#            6       0.50      0.41      0.45        22
#            7       0.58      0.54      0.56        28
#            8       0.74      0.70      0.72        33
#            9       0.82      0.72      0.77        25
#           10       0.75      0.56      0.64        27
#           11       0.71      0.85      0.77        20
#           12       0.31      0.21      0.25        24
#           13       0.79      0.48      0.59        23
#           14       0.76      0.57      0.65        28
#           15       0.67      0.55      0.60        29
#           16       0.56      0.67      0.61        21
#           17       0.59      0.72      0.65        18
#           18       0.35      0.65      0.46        26
#           19       0.25      0.07      0.11        14
#
#     accuracy                           0.55       500
#    macro avg       0.58      0.54      0.54       500
# weighted avg       0.59      0.55      0.56       500

# %% [markdown]
# Now we will use [grid search cross-validation](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html) to find model with the best hyperparameters

# %% [markdown]
# ![5CV](https://scikit-learn.org/stable/_images/grid_search_cross_validation.png)

# %%
from sklearn.model_selection import GridSearchCV

params = {'tfidf__ngram_range':[(1,1),(2,2)],
          'nb__n_neighbors':[1,3,5]}

# Define GridSearchCV
gridcv = GridSearchCV(pipeline, params,
                      scoring='f1_macro', cv=3)

# Fit and cross-validate the model on 3-fold data
gridcv.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('nb', KNeighborsClassifier())]),
#              param_grid={'nb__n_neighbors': [1, 3, 5],
#                          'tfidf__ngram_range': [(1, 1), (2, 2)]},
#              scoring='f1_macro')

# %%
gridcv.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('nb', KNeighborsClassifier(n_neighbors=1))])

# %%
# Make predictions on the test set
ypred = gridcv.predict(Xtest)

# Report classification scores
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.52      0.37        21
#            1       0.38      0.43      0.40        21
#            2       0.54      0.54      0.54        26
#            3       0.46      0.38      0.42        34
#            4       0.81      0.50      0.62        34
#            5       0.68      0.50      0.58        26
#            6       0.41      0.41      0.41        22
#            7       0.67      0.57      0.62        28
#            8       0.82      0.70      0.75        33
#            9       0.69      0.72      0.71        25
#           10       0.68      0.56      0.61        27
#           11       0.70      0.80      0.74        20
#           12       0.43      0.42      0.43        24
#           13       0.65      0.57      0.60        23
#           14       0.64      0.64      0.64        28
#           15       0.48      0.52      0.50        29
#           16       0.63      0.57      0.60        21
#           17       0.43      0.56      0.49        18
#           18       0.39      0.65      0.49        26
#           19       0.55      0.43      0.48        14
#
#     accuracy                           0.55       500
#    macro avg       0.57      0.55      0.55       500
# weighted avg       0.58      0.55      0.56       500

# %% [markdown]
# #### Exercise 2:
#
# 1. Use grid search 5-fold cross-validation across different values of the following two kNN parameters: `n_neighbors` and `metric`  **on the training set** to find the best model.
#
# 2. For the best value of `n_neighbors` and `metric` you found above, compute the `f1_macro` score **on the test set**.
# * Print the value of `n_neighbors` and `metric`.
# * Print the model's `f1_macro` score.

# %%
params = {
    'nb__n_neighbors': [1, 3, 5, 7, 9, 11],
    'nb__metric': ['euclidean', 'manhattan']
}

# %%
gridcv = GridSearchCV(pipeline, params, cv=5, scoring='f1_macro', n_jobs=-1)

# %%
gridcv.fit(Xtrain, ytrain)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('nb', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'nb__metric': ['euclidean', 'manhattan'],
#                          'nb__n_neighbors': [1, 3, 5, 7, 9, 11]},
#              scoring='f1_macro')

# %%
gridcv.best_estimator_
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('nb',
#                  KNeighborsClassifier(metric='euclidean', n_neighbors=1))])

# %%
ypred = gridcv.predict(Xtest)

print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.29      0.52      0.37        21
#            1       0.38      0.43      0.40        21
#            2       0.54      0.54      0.54        26
#            3       0.46      0.38      0.42        34
#            4       0.81      0.50      0.62        34
#            5       0.68      0.50      0.58        26
#            6       0.41      0.41      0.41        22
#            7       0.67      0.57      0.62        28
#            8       0.82      0.70      0.75        33
#            9       0.69      0.72      0.71        25
#           10       0.68      0.56      0.61        27
#           11       0.70      0.80      0.74        20
#           12       0.43      0.42      0.43        24
#           13       0.65      0.57      0.60        23
#           14       0.64      0.64      0.64        28
#           15       0.48      0.52      0.50        29
#           16       0.63      0.57      0.60        21
#           17       0.43      0.56      0.49        18
#           18       0.39      0.65      0.49        26
#           19       0.55      0.43      0.48        14
#
#     accuracy                           0.55       500
#    macro avg       0.57      0.55      0.55       500
# weighted avg       0.58      0.55      0.56       500
